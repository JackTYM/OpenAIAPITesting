# %%
import os
import openai
from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')
print(os.getenv('OPENAI_API_KEY'))
# Out:
# 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

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

def get_completion_from_messages(messages, model="gpt-3.5-turbo", temperature=0):
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=temperature, # this is the degree of randomness of the model's output
    )
#     print(str(response.choices[0].message))
    return response.choices[0].message["content"]

def collect_messages(_):
    prompt = inp.value_input
    inp.value = ''
    context.append({'role':'user', 'content':f"{prompt}"})
    response = get_completion_from_messages(context) 
    context.append({'role':'assistant', 'content':f"{response}"})
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, style={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
Homework Study Guide Creator

# %%
notes = f"""
KEY CONCEPT
Populations, not individuals, evolve.

Natural selection acts on distributions of traits.

A normal distribution graphs as a bell-shaped curve.

Traits not undergoing
natural selection have a
normal distribution.

highest frequency near
mean value

frequencies decrease
toward each extreme
value

Microevolution

Microevolution is the change in allele frequencies that
occurs over time within a population.

Natural selection can take one of three
paths.

Directional selection favors phenotypes at one
extreme.

Stabilizing selection favors the
intermediate phenotype.

Natural selection can take one of three
paths.

Natural selection can take one of three
paths.

Disruptive selection favors both
extreme phenotypes.
"""

prompt = f"""
You will create a Study Guide based off of a set of notes.

Each question you create should have the following values:

Question, Correct Answer, Incorrect Answer, Incorrect Answer, Incorrect Answer

The study guide should be in a json array of questions in the following format:

[
    {{
        Question: (Question),
        Correct: (Correct Answer),
        Incorrect: [
            (Incorrect Answer),
            (Incorrect Answer),
            (Incorrect Answer)
        ]
    }}
]

The notes are listed below.

```{notes}```
"""

response = get_completion(prompt)
print(response)
# Out:
# [
#     {
#         "Question": "What is the key concept of evolution?",
#         "Correct": "Populations, not individuals, evolve.",
#         "Incorrect": [
#             "Individuals, not populations, evolve.",
#             "Evolution only occurs in extreme environments.",
#             "Evolution is a random process."
#         ]
#     },
#     {
#         "Question": "What does natural selection act on?",
#         "Correct": "Distributions of traits.",
#         "Incorrect": [
#             "Individual traits.",
#             "The entire population.",
#             "Environmental factors."
#         ]
#     },
#     {
#         "Question": "What does a normal distribution graph as?",
#         "Correct": "A bell-shaped curve.",
#         "Incorrect": [
#             "A straight line.",
#             "A parabola.",
#             "A sinusoidal wave."
#         ]
#     },
#     {
#         "Question": "What type of distribution do traits not undergoing natural selection have?",
#         "Correct": "A normal distribution.",
#         "Incorrect": [
#             "A bimodal distribution.",
#             "A uniform distribution.",
#             "A skewed distribution."
#         ]
#     },
#     {
#         "Question": "Where is the highest frequency in a normal distribution?",
#         "Correct": "Near the mean value.",
#         "Incorrect": [
#             "At the extreme values.",
#             "In the middle of the distribution.",
#             "It varies depending on the trait."
#         ]
#     },
#     {
#         "Question": "How do frequencies change in a normal distribution?",
#         "Correct": "Frequencies decrease toward each extreme value.",
#         "Incorrect": [
#             "Frequencies increase toward each extreme value.",
#             "Frequencies remain constant throughout the distribution.",
#             "It varies depending on the trait."
#         ]
#     },
#     {
#         "Question": "What is microevolution?",
#         "Correct": "The change in allele frequencies that occurs over time within a population.",
#         "Incorrect": [
#             "The change in allele frequencies that occurs between populations.",
#             "The change in phenotype that occurs over time within a population.",
#             "The change in genotype that occurs over time within a population."
#         ]
#     },
#     {
#         "Question": "What are the three paths that natural selection can take?",
#         "Correct": "Directional selection, stabilizing selection, and disruptive selection.",
#         "Incorrect": [
#             "Positive selection, negative selection, and neutral selection.",
#             "Intrasexual selection, intersexual selection, and kin selection.",
#             "Artificial selection, sexual selection, and natural selection."
#         ]
#     },
#     {
#         "Question": "What does directional selection favor?",
#         "Correct": "Phenotypes at one extreme.",
#         "Incorrect": [
#             "Phenotypes at the mean.",
#             "Phenotypes at both extremes.",
#             "It varies depending on the trait."
#         ]
#     },
#     {
#         "Question": "What does stabilizing selection favor?",
#         "Correct": "The intermediate phenotype.",
#         "Incorrect": [
#             "Phenotypes at one extreme.",
#             "Phenotypes at the mean.",
#             "Phenotypes at both extremes."
#         ]
#     },
#     {
#         "Question": "What does disruptive selection favor?",
#         "Correct": "Both extreme phenotypes.",
#         "Incorrect": [
#             "The intermediate phenotype.",
#             "Phenotypes at one extreme.",
#             "Phenotypes at the mean."
#         ]
#     }
# ]
